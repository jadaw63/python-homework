# %%
# Part of this code was used from the class activities

# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvfile = Path('../Resources/budget_data.csv')

# Declare Variables
months = 0 
total = 0
average = 0
minimum = 0
maximum = 0


#Empty lists
profitable_dates = []
unprofitable_dates = []

#Code from https://www.guru99.com/python-csv.html
import csv
# Check the current directory where the Python program is executing from
print(f"Current Working Directory: {Path.cwd()}")

with open('../Resources/budget_data.csv','rt') as f:
  next(f)
  dataset = csv.reader(f)
  for i in dataset:
    date = i[0]
    pnl = float(i[1])
    total_pnl += pnl
    total_row = date,pnl
        
    # Sum up the total and count
    total += pnl
    months += 1
     
    #Logic to determine minimum values
    if total > maximum:
        maximum = total
        
    # Find minimum and maximum values

    if minimum == 0:
        minimum = total
    elif value < minimum:
        minimum = total
    elif value > minimum:
        minimum = total

    # Add profitable days to a list
    if total > 0:
        profitable_dates.append(pnl)
    elif total < 0:
        unprofitable_dates.append(pnl)
        
# Calculate the average

def average_change(total, months):
    average_pnl_change = (total / months)
    
    average_pnl_change_formatted = round(average_pnl_change, 2)
    
    return average_pnl_change_formatted

average = average_change(total, months)

#Find increased and decreased profits
inc_profits = (max(profitable_dates))
dec_profits = (min(profitable_dates))


print("-----Financial Analysis------")
print(f"Total Months: {months}")
print(f"Total Value: {total}")
print(f"Average Change: $ {average} ")
print(f"Greatest Increase in Profits: {date} {inc_profits} ")
print(f"Greatest Decrease in Profits: {date} {dec_profits} ")

# Set output file name
export_file_path = 'homeworkTwoFileExport.txt'

# Open the output path as a file object
with open(export_file_path, 'w') as file:
    # Write daily_average to the output file, convert to string
    file.write("-----Financial Analysis------ \n")
    file.write(f"Total Months: {months} \n")
    file.write(f"Total Value: {total} \n ")
    file.write(f"Greatest Increase in Profits: {date} {inc_profits} \n")
    file.write(f"Greatest Decrease in Profits: {date} {dec_profits}")
# Out:
# Current Working Directory: C:\Users\Japes\Desktop\yep\GWFinTech\python-homework\PyBank
# -----Financial Analysis------
# Total Months: 86
# Total Value: 38382578.0
# Average Change: $ 446309.05
# Greatest Increase in Profits: 17-Feb 1170593.0
# Greatest Decrease in Profits: 17-Feb -1196225.0
